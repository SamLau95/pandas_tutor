# %%
# !pip install pandas-tutor==2.0.1

# %%
# %reload_ext pandas_tutor
# Out:
# <script type="text/javascript" src="https://pandastutor.com/build/wsembed.bundle.2022-07-07-release.js"></script>
# <script>
# console.log("initializing pandas_tutor js")
#
# function drawWsv(viz_id, spec, options) {
#   if (typeof createWsvFromPandasTrace === 'undefined') {
#     setTimeout(() => drawWsv(viz_id, spec, options), 2000) // retry in 2 seconds
#     return
#   }
#   createWsvFromPandasTrace(viz_id, spec, options)
# }
# </script>

# %%
import pandas as pd
import numpy as np
import io

# test case for getCall

num_rows = 500  # 1 million rows
num_columns = 500    # 50 columns

# Create a DataFrame with random floats
dogs = pd.DataFrame(np.random.rand(num_rows, num_columns), columns=[f'col{i}' for i in range(num_columns)])


dogs
# Out:
#          col0      col1      col2      col3      col4      col5      col6  \
# 0    0.336920  0.177668  0.836857  0.873303  0.425947  0.689505  0.492651
# 1    0.915831  0.078075  0.667453  0.002722  0.475225  0.124573  0.879775
# 2    0.208634  0.635764  0.711770  0.039870  0.775145  0.693154  0.252532
# 3    0.353119  0.951360  0.071336  0.611768  0.894488  0.814843  0.169269
# 4    0.629302  0.269764  0.741965  0.525862  0.297470  0.557083  0.618058
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.228220  0.869194  0.608070  0.656503  0.295654  0.449890  0.139540
# 496  0.504915  0.492770  0.261472  0.063877  0.047953  0.645530  0.025376
# 497  0.509789  0.721815  0.702204  0.103355  0.700276  0.000296  0.155670
# 498  0.248367  0.262918  0.106821  0.258641  0.206921  0.158614  0.226204
# 499  0.789609  0.442182  0.452807  0.712942  0.949656  0.612535  0.239780
#
#          col7      col8      col9  ...    col490    col491    col492  \
# 0    0.544113  0.602722  0.047968  ...  0.291057  0.996712  0.694118
# 1    0.891780  0.240151  0.575662  ...  0.076537  0.380141  0.789719
# 2    0.702762  0.936572  0.788208  ...  0.206806  0.245555  0.344553
# 3    0.140014  0.673706  0.411221  ...  0.389277  0.905016  0.292531
# 4    0.264929  0.698367  0.855338  ...  0.933421  0.482119  0.408214
# ..        ...       ...       ...  ...       ...       ...       ...
# 495  0.866655  0.058181  0.336569  ...  0.251925  0.922985  0.551066
# 496  0.227946  0.856525  0.657950  ...  0.228374  0.648276  0.596652
# 497  0.470695  0.862942  0.899957  ...  0.230843  0.323105  0.421468
# 498  0.645926  0.353124  0.764296  ...  0.794374  0.983684  0.405271
# 499  0.625589  0.342898  0.152348  ...  0.701580  0.571148  0.093122
#
#        col493    col494    col495    col496    col497    col498    col499
# 0    0.591066  0.098015  0.729859  0.509496  0.164296  0.078911  0.017822
# 1    0.833414  0.570289  0.493759  0.448766  0.829320  0.411060  0.304272
# 2    0.122345  0.512431  0.009700  0.679230  0.816257  0.051385  0.058661
# 3    0.562185  0.109740  0.225380  0.864160  0.440275  0.923849  0.371408
# 4    0.674040  0.696856  0.935262  0.122042  0.447744  0.839012  0.306361
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.466394  0.563451  0.986480  0.645712  0.594535  0.865999  0.863900
# 496  0.010900  0.634235  0.303691  0.045890  0.220293  0.930316  0.033670
# 497  0.808716  0.029591  0.756012  0.208399  0.212488  0.428013  0.731760
# 498  0.264918  0.920218  0.995506  0.975132  0.711193  0.035764  0.009814
# 499  0.397685  0.521295  0.496053  0.931791  0.507783  0.966422  0.240440
#
# [500 rows x 500 columns]

# %%
# %%pt
#
# #dogs.get(['Name'])
# #dogs.get('Name')
# dogs.get(['Name1', 'Name2']).get('Name')
# Out:
# DFResult(step=StartOfChain(code="dogs.get(['Name1', 'Name2']).get('Name')", location=CodeRange(start=CodePosition(line=3, ch=0), end=CodePosition(line=3, ch=4))), fragment=CodeRange(start=CodePosition(line=0, ch=0), end=CodePosition(line=0, ch=4)), args={}, val=         col0      col1      col2      col3      col4      col5      col6  \
# 0    0.336920  0.177668  0.836857  0.873303  0.425947  0.689505  0.492651
# 1    0.915831  0.078075  0.667453  0.002722  0.475225  0.124573  0.879775
# 2    0.208634  0.635764  0.711770  0.039870  0.775145  0.693154  0.252532
# 3    0.353119  0.951360  0.071336  0.611768  0.894488  0.814843  0.169269
# 4    0.629302  0.269764  0.741965  0.525862  0.297470  0.557083  0.618058
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.228220  0.869194  0.608070  0.656503  0.295654  0.449890  0.139540
# 496  0.504915  0.492770  0.261472  0.063877  0.047953  0.645530  0.025376
# 497  0.509789  0.721815  0.702204  0.103355  0.700276  0.000296  0.155670
# 498  0.248367  0.262918  0.106821  0.258641  0.206921  0.158614  0.226204
# 499  0.789609  0.442182  0.452807  0.712942  0.949656  0.612535  0.239780
#
#          col7      col8      col9  ...    col490    col491    col492  \
# 0    0.544113  0.602722  0.047968  ...  0.291057  0.996712  0.694118
# 1    0.891780  0.240151  0.575662  ...  0.076537  0.380141  0.789719
# 2    0.702762  0.936572  0.788208  ...  0.206806  0.245555  0.344553
# 3    0.140014  0.673706  0.411221  ...  0.389277  0.905016  0.292531
# 4    0.264929  0.698367  0.855338  ...  0.933421  0.482119  0.408214
# ..        ...       ...       ...  ...       ...       ...       ...
# 495  0.866655  0.058181  0.336569  ...  0.251925  0.922985  0.551066
# 496  0.227946  0.856525  0.657950  ...  0.228374  0.648276  0.596652
# 497  0.470695  0.862942  0.899957  ...  0.230843  0.323105  0.421468
# 498  0.645926  0.353124  0.764296  ...  0.794374  0.983684  0.405271
# 499  0.625589  0.342898  0.152348  ...  0.701580  0.571148  0.093122
#
#        col493    col494    col495    col496    col497    col498    col499
# 0    0.591066  0.098015  0.729859  0.509496  0.164296  0.078911  0.017822
# 1    0.833414  0.570289  0.493759  0.448766  0.829320  0.411060  0.304272
# 2    0.122345  0.512431  0.009700  0.679230  0.816257  0.051385  0.058661
# 3    0.562185  0.109740  0.225380  0.864160  0.440275  0.923849  0.371408
# 4    0.674040  0.696856  0.935262  0.122042  0.447744  0.839012  0.306361
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.466394  0.563451  0.986480  0.645712  0.594535  0.865999  0.863900
# 496  0.010900  0.634235  0.303691  0.045890  0.220293  0.930316  0.033670
# 497  0.808716  0.029591  0.756012  0.208399  0.212488  0.428013  0.731760
# 498  0.264918  0.920218  0.995506  0.975132  0.711193  0.035764  0.009814
# 499  0.397685  0.521295  0.496053  0.931791  0.507783  0.966422  0.240440
#
# [500 rows x 500 columns])
# UnhandledResult(step=GetCall(code="dogs.get(['Name1', 'Name2']).get('Name')", location=CodeRange(start=CodePosition(line=3, ch=4), end=CodePosition(line=3, ch=28)), labels_expr="['Name1', 'Name2']"), fragment=CodeRange(start=CodePosition(line=0, ch=4), end=CodePosition(line=0, ch=28)), args={'labels': ['Name1', 'Name2']}, val=None)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('pt', '', "\n#dogs.get(['Name'])\n#dogs.get('Name')\ndogs.get(['Name1', 'Name2']).get('Name')\n")
#
# File ~/miniforge3/envs/dsc80/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/ipython_magics.py:144, in PandasTutorMagics.pt(self, line, cell)
#     142 @cell_magic
#     143 def pt(self, line: str, cell: str):
# --> 144     return self.pandas_tutor(line, cell)
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/ipython_magics.py:127, in PandasTutorMagics.pandas_tutor(self, line, cell)
#     124 @cell_magic
#     125 def pandas_tutor(self, line: str, cell: str):
#     126     # inherits self.shell from Magics parent class
# --> 127     spec = pt.make_tutor_spec_ipython(cell, self.shell)
#     128     # need to double wrap so that quotes and \n are escaped
#     129     spec_json = json.dumps(spec)
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/__main__.py:40, in make_tutor_spec_ipython(code, ipython_shell)
#      38 root = parse(code)
#      39 eval_results = run(root, ipython_shell)
# ---> 40 explanation = serialize(eval_results)
#      41 spec = OutputSpec(code=code, explanation=explanation)
#      42 return spec.to_json()
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/serialize.py:77, in serialize(results)
#      72 if len(results) == 1:
#      73     # happens when user inputs `df` without a function call, or when
#      74     # error happens in setup code
#      75     return serialize_single(results[0])
# ---> 77 return [serialize_pair(before, after) for before, after in pairs(results)]
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/serialize.py:77, in <listcomp>(.0)
#      72 if len(results) == 1:
#      73     # happens when user inputs `df` without a function call, or when
#      74     # error happens in setup code
#      75     return serialize_single(results[0])
# ---> 77 return [serialize_pair(before, after) for before, after in pairs(results)]
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/serialize.py:110, in serialize_pair(before, after)
#     108 print(before)
#     109 print(after)
# --> 110 before.val, after.val = reduce_memory(before.val, after.val, step)
#     114 marks = make_marks(step, before, after)
#     116 # lhs: Union[DataSpec, PrevRHS] = (
#     117 #     serialize_step_val(before)
#     118 #     if isinstance(before.step, StartOfChain)
#     119 #     else "prev_rhs"
#     120 # )
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/reduce.py:77, in reduce_memory(before, after, step)
#      74 else: # don't know what to do, so just do nothing
#      75     before_imp, after_imp = before, after
# ---> 77 before_main = grab_important(before_imp, before)
#      78 after_main = grab_important(after_imp, after)
#      80 # Indicate the rows you want to keep from after.val because before.val was already ripped from?
#      81 # Gonna need some flag to indicate that it's the first in the chain and to edit the LHS
#      82 # if isinstance(step, HeadCall):
#      83 #     before = before.head(1)
#      84 #     after = after.head(1)
#
# File /mnt/c/Users/guoxu/local_repos/pandas_tutor/pandas_tutor/reduce.py:116, in grab_important(important_score, obj)
#     113 row_score = important_score[0]
#     114 col_score = important_score[1]
# --> 116 key_rows = [i[0] for i in sorted(row_score.items(), key= lambda item: item[1], reverse=True)[:MAX_ROWS]]
#     117 if isinstance(obj, pd.DataFrame):
#     118     # get the most important row and columns names
#     119     key_columns = [i[0] for i in sorted(col_score.items(), key= lambda item: item[1], reverse=True)[:MAX_ROWS]]
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
941180 / 51208384

# %%
# %%pt
# (dogs[dogs['size'] == 'medium']
#  .sort_values('type')
#  .groupby('type').median()
#  .stack()
#  .unstack()
#  .stack()
# )
# # if you make the cell viewport small and render, then resize, sometimes arrows and highlights
# # are in the wrong positions. i added a 'repaint diagram' link to the bottom to manually fix it
# # since it's too hard to automatically detect these changes
